# %%
import src.service as s
# Out:
# 2024-12-08 14:16:37.759 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-12-08 14:16:37.761 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
file_mapping = {
    "co2_per_capita": "data/co2-emissions-per-capita.csv",
    "Renewables": "data/renewable-share-energy.csv",
    "Carbon_tax": "data/emissions-weighted-carbon-price.csv",
    "Life_expectancy": "data/life-expectancy.csv",
    "GDP_per_capita": "data/gdp-per-capita-worldbank.csv",
}

# %%
dataframes = {name: s.load_default_file(path) for name, path in file_mapping.items()}

merged_dataframe = s.merge_dataframes(dataframes)
# Out:
# 2024-12-08 14:16:37.788 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.682
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\mytti\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-12-08 14:16:38.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.685 No runtime found, using MemoryCacheStorageManager
# 2024-12-08 14:16:38.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.770 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-08 14:16:38.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
merged_dataframe[merged_dataframe["country"].isin(s.get_countries_by_continent([merged_dataframe], "Oceania"))]
# Out:
#                  country Code  year  co2_per_capita  Renewables  Carbon_tax  \
# 1504           Australia  AUS  1750             0.0         NaN         NaN
# 1505           Australia  AUS  1760             0.0         NaN         NaN
# 1506           Australia  AUS  1770             0.0         NaN         NaN
# 1507           Australia  AUS  1780             0.0         NaN         NaN
# 1508           Australia  AUS  1790             0.0         NaN         NaN
# ...                  ...  ...   ...             ...         ...         ...
# 30420  Wallis and Futuna  WLF  1985             NaN         NaN         NaN
# 30421  Wallis and Futuna  WLF  1986             NaN         NaN         NaN
# 30422  Wallis and Futuna  WLF  1987             NaN         NaN         NaN
# 30423  Wallis and Futuna  WLF  1988             NaN         NaN         NaN
# 30424  Wallis and Futuna  WLF  1989             NaN         NaN         NaN
#
#        Life_expectancy  GDP_per_capita
# 1504               NaN             NaN
# 1505               NaN             NaN
# 1506               NaN             NaN
# 1507               NaN             NaN
# 1508               NaN             NaN
# ...                ...             ...
# 30420          63.7294             NaN
# 30421          64.6043             NaN
# 30422          65.7918             NaN
# 30423          68.4445             NaN
# 30424          69.0866             NaN
#
# [1930 rows x 8 columns]
