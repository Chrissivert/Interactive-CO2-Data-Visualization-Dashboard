# %%
import pandas as pd

dataframe = pd.read_csv("data/owid-co2-data.csv")
dataframe
# Out:
#         country  year iso_code  population           gdp  cement_co2  \
# 0       Andorra  1750      AND      2221.0           NaN       0.000
# 1       Andorra  1751      AND         NaN           NaN       0.000
# 2       Andorra  1752      AND         NaN           NaN       0.000
# 3       Andorra  1753      AND         NaN           NaN       0.000
# 4       Andorra  1754      AND         NaN           NaN       0.000
# ...         ...   ...      ...         ...           ...         ...
# 46864  Zimbabwe  2018      ZWE  15052191.0  2.678627e+10       0.558
# 46865  Zimbabwe  2019      ZWE  15354606.0  2.514642e+10       0.473
# 46866  Zimbabwe  2020      ZWE  15669663.0  2.317871e+10       0.496
# 46867  Zimbabwe  2021      ZWE  15993525.0  2.514009e+10       0.531
# 46868  Zimbabwe  2022      ZWE  16320539.0  2.590159e+10       0.531
#
#        cement_co2_per_capita     co2  co2_growth_abs  co2_growth_prct  ...  \
# ...

# %%
countries = ["Japan"]

years = set()
years.update(dataframe[dataframe["country"].isin(countries)]["year"].unique())
sorted(years)
# Out:
# [1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1857,
#  1858,
#  1859,
#  1860,
#  1861,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1867,
#  1868,
#  1869,
#  1870,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
#  1911,
#  1912,
#  1913,
#  1914,
#  1915,
#  1916,
#  1917,
#  1918,
#  1919,
#  1920,
#  1921,
#  1922,
#  1923,
#  1924,
#  1925,
#  1926,
#  1927,
#  1928,
#  1929,
#  1930,
#  1931,
#  1932,
#  1933,
#  1934,
#  1935,
#  1936,
#  1937,
#  1938,
#  1939,
#  1940,
#  1941,
#  1942,
#  1943,
#  1944,
#  1945,
#  1946,
#  1947,
#  1948,
#  1949,
#  1950,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1957,
#  1958,
#  1959,
#  1960,
# ...
